# %%
state = 'ME' 
year = 2020

# %%
import sys, os
src_path = os.path.abspath(os.path.join('..', '..', 'src'))
sys.path.append(src_path)

# %%
filepath = '../../dat/' + str(year) + '/'
filename = state + '_county.json'
filename2 = state + '_county.shp'

# %%
from read import read_graph_from_json
from epsilon_constraint import*
import networkx as nx

G = read_graph_from_json(state, filepath + filename, year=year)
print(f"The state of {state} has {G._k} districts.")
G._ideal_population = sum(G.nodes[i]['TOTPOP'] for i in G.nodes) / G._k
# Out:
# The state of ME has 2 districts.

# %%
#import warm starts
sys.path.append(os.path.abspath('../heuristic'))

from ME_plans_2020 import plans
print(f"Loaded {len(plans)} plans from file.")
warm_starts = plans
# Out:
# Loaded 8 plans from file.

# %%
obj_type = 'average_Polsby_Popper'
starting_deviation = 0.01 
verbose = True
contiguity = 'lcut'               # {'lcut', 'scf', 'shir'}
warm_start_mode = 'user'          # {'None', 'user', 'refinement'}
warm_starts = warm_starts         # if you have user define warm starts else it is None
time_limit = 7200                 # Time limit in seconds, adjust as needed
multiplier = 0                    # Adjust multiplier as needed
max_B = True                      # If symmetry_breaking is 'orbitope' or you have warm_start, max_B should be True
symmetry_breaking = 'orbitope'    # {None, 'orbitope', 'rsum'}              
sizes = None

# %%
print(f"Running epsilon constraint method for state {state}, objective {obj_type}")
print(f"{'#' * 100}\n")
(plans, obj_bounds, deviations) = epsilon_constraint_method(
            G,                 
            obj_type,          
            contiguity,        
            cutoff=None,       
            verbose=verbose,
            warm_start_mode = warm_start_mode,
            warm_starts=warm_starts,  
            starting_deviation=starting_deviation, 
            time_limit=time_limit, 
            sizes=sizes,      
            max_B=max_B,      
            symmetry_breaking=symmetry_breaking, 
            state=state,
            year=year
        )
# Out:
# Running epsilon constraint method for state ME, objective average_Polsby_Popper
# ####################################################################################################
#
# L = 674368 and U = 687991
#
# ****************************************
# Trying deviation = 6811.795
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[0, 3, 6, 12], [1, 2, 4, 5, 7, 8, 9, 10, 11, 13, 14, 15]]
# Objective value: 0.33204492607301983
# Deviation: 2777.5
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 674368 and U = 687991
# Set parameter Username
# Set parameter LicenseID to value 2608266
# Academic license - for non-commercial use only - expires 2026-01-09
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 578 rows, 450 columns and 1837 nonzeros
# Model fingerprint: 0xd02ed0ac
# Model has 2 quadratic constraints
# Variable types: 142 continuous, 308 integer (308 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [5e-07, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 0.263927 (0.03s)
# User MIP start produced solution with objective 0.326427 (0.03s)
# User MIP start produced solution with objective 0.332045 (0.03s)
# Loaded user MIP start with objective 0.332045
#
# Presolve removed 268 rows and 192 columns
# Presolve time: 0.01s
# Presolved: 310 rows, 258 columns, 1089 nonzeros
# Presolved model has 2 quadratic constraint(s)
# Variable types: 46 continuous, 212 integer (212 binary)
#
# Root relaxation: objective 9.999990e-01, 76 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00000    0    2    0.33204    1.00000   201%     -    0s
#      0     0    0.99573    0   33    0.33204    0.99573   200%     -    0s
#      0     0    0.99165    0   34    0.33204    0.99165   199%     -    0s
#      0     0    0.99131    0   33    0.33204    0.99131   199%     -    0s
#      0     0    0.95573    0   62    0.33204    0.95573   188%     -    0s
#      0     0    0.95551    0   62    0.33204    0.95551   188%     -    0s
#      0     0    0.95355    0   59    0.33204    0.95355   187%     -    0s
#      0     0    0.95321    0   64    0.33204    0.95321   187%     -    0s
#      0     0    0.95027    0   74    0.33204    0.95027   186%     -    0s
#      0     0    0.94946    0   78    0.33204    0.94946   186%     -    0s
#      0     0    0.94907    0   76    0.33204    0.94907   186%     -    0s
#      0     0    0.94893    0   76    0.33204    0.94893   186%     -    0s
#      0     0    0.94889    0   74    0.33204    0.94889   186%     -    0s
#      0     0    0.94885    0   61    0.33204    0.94885   186%     -    0s
#      0     2    0.94869    0   61    0.33204    0.94869   186%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 5
#   Implied bound: 14
#   MIR: 34
#   StrongCG: 1
#   Flow cover: 37
#   Zero half: 3
#   RLT: 52
#
# Explored 535 nodes (19038 simplex iterations) in 0.88 seconds (0.24 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 0.332045 0.326427 0.263927
# No other solutions better than 0.332045
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 3.320446014404e-01, best bound 3.320446014404e-01, gap 0.0000%
#
# User-callback calls 1661, time in user-callback 0.02 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[0, 3, 6, 12], [1, 2, 4, 5, 7, 8, 9, 10, 11, 13, 14, 15]]
#
# ****************************************
# Trying deviation = 2777.25
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[0, 5, 6, 7, 8, 13], [1, 2, 3, 4, 9, 10, 11, 12, 14, 15]]
# Objective value: 0.20765187988935258
# Deviation: 1882.5
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 678403 and U = 683956
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 578 rows, 450 columns and 1837 nonzeros
# Model fingerprint: 0xea66e9d9
# Model has 2 quadratic constraints
# Variable types: 142 continuous, 308 integer (308 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [5e-07, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 0.206579 (0.03s)
# User MIP start produced solution with objective 0.207555 (0.03s)
# User MIP start produced solution with objective 0.207652 (0.03s)
# Loaded user MIP start with objective 0.207652
#
# Presolve removed 268 rows and 192 columns
# Presolve time: 0.01s
# Presolved: 310 rows, 258 columns, 1089 nonzeros
# Presolved model has 2 quadratic constraint(s)
# Variable types: 46 continuous, 212 integer (212 binary)
#
# Root relaxation: objective 9.999990e-01, 76 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00000    0    2    0.20765    1.00000   382%     -    0s
#      0     0    0.99554    0   32    0.20765    0.99554   379%     -    0s
#      0     0    0.99075    0   44    0.20765    0.99075   377%     -    0s
#      0     0    0.97293    0   65    0.20765    0.97293   369%     -    0s
#      0     0    0.97136    0   65    0.20765    0.97136   368%     -    0s
#      0     0    0.94413    0   71    0.20765    0.94413   355%     -    0s
#      0     0    0.94219    0   76    0.20765    0.94219   354%     -    0s
#      0     0    0.93891    0   82    0.20765    0.93891   352%     -    0s
#      0     0    0.93803    0   80    0.20765    0.93803   352%     -    0s
#      0     0    0.91724    0   94    0.20765    0.91724   342%     -    0s
#      0     0    0.91532    0   96    0.20765    0.91532   341%     -    0s
#      0     0    0.90578    0   93    0.20765    0.90578   336%     -    0s
#      0     0    0.90353    0   97    0.20765    0.90353   335%     -    0s
#      0     0    0.88668    0   96    0.20765    0.88668   327%     -    0s
#      0     0    0.88360    0   94    0.20765    0.88360   326%     -    0s
#      0     0    0.88197    0   95    0.20765    0.88197   325%     -    0s
#      0     0    0.88197    0   95    0.20765    0.88197   325%     -    0s
#      0     0    0.88154    0   95    0.20765    0.88154   325%     -    0s
#      0     2    0.88137    0   95    0.20765    0.88137   324%     -    0s
#
# Cutting planes:
#   Lazy constraints: 1
#
# Explored 2591 nodes (66699 simplex iterations) in 2.03 seconds (0.73 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 0.207652 0.207555 0.206579
# No other solutions better than 0.207652
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.076516151428e-01, best bound 2.076516151428e-01, gap 0.0000%
#
# User-callback calls 5908, time in user-callback 0.05 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[1, 2, 3, 4, 9, 10, 11, 12, 14, 15], [0, 5, 6, 7, 8, 13]]
#
# ****************************************
# Trying deviation = 1882.25
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[5, 6, 7, 8, 10, 12, 13, 14], [0, 1, 2, 3, 4, 9, 11, 15]]
# Objective value: 0.17519573386852202
# Deviation: 750.5
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 679298 and U = 683061
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 578 rows, 450 columns and 1837 nonzeros
# Model fingerprint: 0x2402d843
# Model has 2 quadratic constraints
# Variable types: 142 continuous, 308 integer (308 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [5e-07, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 0.12719 (0.02s)
# User MIP start produced solution with objective 0.15844 (0.02s)
# User MIP start produced solution with objective 0.175195 (0.02s)
# Loaded user MIP start with objective 0.175195
#
# Presolve removed 264 rows and 190 columns
# Presolve time: 0.00s
# Presolved: 314 rows, 260 columns, 1101 nonzeros
# Presolved model has 2 quadratic constraint(s)
# Variable types: 46 continuous, 214 integer (214 binary)
#
# Root relaxation: objective 9.999990e-01, 54 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00000    0   13    0.17520    1.00000   471%     -    0s
#      0     0    0.99367    0   46    0.17520    0.99367   467%     -    0s
#      0     0    0.98835    0   43    0.17520    0.98835   464%     -    0s
#      0     0    0.98835    0   43    0.17520    0.98835   464%     -    0s
#      0     0    0.95284    0   67    0.17520    0.95284   444%     -    0s
#      0     0    0.95162    0   67    0.17520    0.95162   443%     -    0s
#      0     0    0.93380    0  115    0.17520    0.93380   433%     -    0s
#      0     0    0.92092    0   50    0.17520    0.92092   426%     -    0s
#      0     0    0.90604    0  100    0.17520    0.90604   417%     -    0s
#      0     0    0.90577    0  116    0.17520    0.90577   417%     -    0s
#      0     0    0.90480    0  111    0.17520    0.90480   416%     -    0s
#      0     0    0.90476    0  110    0.17520    0.90476   416%     -    0s
#      0     0    0.90354    0  125    0.17520    0.90354   416%     -    0s
#      0     0    0.90352    0  119    0.17520    0.90352   416%     -    0s
#      0     0    0.90337    0  125    0.17520    0.90337   416%     -    0s
#      0     2    0.89833    0  125    0.17520    0.89833   413%     -    0s
#
# Cutting planes:
#   Lazy constraints: 4
#
# Explored 2228 nodes (42474 simplex iterations) in 1.75 seconds (0.54 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 0.175195 0.15844 0.12719
# No other solutions better than 0.175195
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.751952171326e-01, best bound 1.751952171326e-01, gap 0.0000%
#
# User-callback calls 5172, time in user-callback 0.06 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[5, 6, 7, 8, 10, 12, 13, 14], [0, 1, 2, 3, 4, 9, 11, 15]]
#
# ****************************************
# Trying deviation = 750.25
# ****************************************
# Using user-provided warm starts.
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 680430 and U = 681929
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 578 rows, 450 columns and 1837 nonzeros
# Model fingerprint: 0x591f6a18
# Model has 2 quadratic constraints
# Variable types: 142 continuous, 308 integer (308 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 3e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [5e-07, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 268 rows and 192 columns
# Presolve time: 0.01s
# Presolved: 310 rows, 258 columns, 1089 nonzeros
# Presolved model has 2 quadratic constraint(s)
# Variable types: 46 continuous, 212 integer (212 binary)
#
# Root relaxation: objective 9.999990e-01, 76 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00000    0    8          -    1.00000      -     -    0s
#      0     0    0.99616    0   50          -    0.99616      -     -    0s
#      0     0    0.98981    0   46          -    0.98981      -     -    0s
#      0     0    0.98981    0   50          -    0.98981      -     -    0s
#      0     0    0.95558    0   73          -    0.95558      -     -    0s
#      0     0    0.91185    0   74          -    0.91185      -     -    0s
#      0     0    0.84964    0   69          -    0.84964      -     -    0s
#      0     0    0.84258    0   74          -    0.84258      -     -    0s
#      0     0    0.84030    0   77          -    0.84030      -     -    0s
#      0     0    0.83972    0   77          -    0.83972      -     -    0s
#      0     0    0.83911    0   74          -    0.83911      -     -    0s
#      0     0    0.83879    0   85          -    0.83879      -     -    0s
#      0     0    0.83783    0   87          -    0.83783      -     -    0s
#      0     0    0.83778    0   87          -    0.83778      -     -    0s
#      0     0    0.83760    0   90          -    0.83760      -     -    0s
#      0     2    0.83698    0   90          -    0.83698      -     -    0s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 3
#   Implied bound: 1
#   MIR: 19
#   Flow cover: 19
#   Zero half: 5
#   RLT: 31
#   Lazy constraints: 15
#
# Explored 3438 nodes (97452 simplex iterations) in 2.27 seconds (0.74 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
# No other solutions better than -1e+100
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 7712, time in user-callback 0.06 sec
# No feasible solution found.
#
# ****************************************
# No feasible solution found! Gurobi status: 3
# ****************************************

# %%
result = list(zip(plans, obj_bounds , deviations))

# %%
# Determine the senses for the Pareto frontier
# Minimize the first objective ('deviation').
# Maximize the second objective for compactness types, otherwise minimize it.
senses = ['min', 'max' if obj_type in ['average_Polsby_Popper','bottleneck_Polsby_Popper'] else 'min']
obj_names = ['deviation_persons', obj_type]
infeasible_region = [0, min(round(r[2],1) for r in result)]

# %%
from pareto import ParetoFrontier

print(f"\n{'#' * 100}\nPareto Frontier for state {state},  objective {obj_type}\n{'#' * 100}\n")
pareto = ParetoFrontier(senses, obj_names, state=state, level='county')

if not  plans:
    print("No plan found!")
else:
    for plan, obj_bound, dev in result:
        upper_bound = [dev,  1/obj_bound[0] if  obj_type == 'bottleneck_Polsby_Popper' else obj_bound[0]]
        lower_bound = [dev,  1/obj_bound[1] if  obj_type == 'bottleneck_Polsby_Popper' else obj_bound[1]]
        
        pareto.add_plan(plan, upper_bound, lower_bound)
            
print("Pareto front plans:", pareto.plans)
print("Pareto front upper bounds:", pareto.upper_bounds)
print("Pareto front lower bounds:", pareto.lower_bounds) 

extra_points = None
extra_colors = None
        
pareto.tighten_lower_bounds()

if infeasible_region[1] > 0.5:
    max_dev = max(upper_bound[0] for upper_bound in pareto.upper_bounds)
    max_obj = max(upper_bound[1] for upper_bound in pareto.upper_bounds)
    min_obj = min(upper_bound[1] for upper_bound in pareto.upper_bounds)
    o1lim=[-1, max_dev+100]
    o2lim=[min_obj*0.9, max_obj*(1.1)]
else:
    o1lim = None
    o2lim = None

pareto.plot_with_custom_x_ranges(method = 'epsilon_constraint_method', 
                                 o1lim=o1lim, o2lim=o2lim, infeasible_region = infeasible_region,
                                 extra_points=extra_points, extra_colors=extra_colors)
# Out:
# ####################################################################################################
# Pareto Frontier for state ME,  objective average_Polsby_Popper
# ####################################################################################################
#
# Pareto front plans: [[[5, 6, 7, 8, 10, 12, 13, 14], [0, 1, 2, 3, 4, 9, 11, 15]], [[1, 2, 3, 4, 9, 10, 11, 12, 14, 15], [0, 5, 6, 7, 8, 13]], [[0, 3, 6, 12], [1, 2, 4, 5, 7, 8, 9, 10, 11, 13, 14, 15]]]
# Pareto front upper bounds: [[750.5, 0.17519521713256836], [1882.5, 0.20765161514282227], [2777.5, 0.3320446014404297]]
# Pareto front lower bounds: [[750.5, 0.17519521713256836], [1882.5, 0.20765161514282227], [2777.5, 0.3320446014404297]]

# %%
from draw import *

print(f"\n{'#' * 100}\nPareto maps for state {state}, objective {obj_type}\n{'#' * 100}\n")

format_obj = {
    'bottleneck_Polsby_Popper': lambda x: round(1 /x, 4),
    'cut_edges': lambda x: round(x, 0)}

for plan, obj_bound, dev in result:
    ub = format_obj.get(obj_type, lambda x: round(x, 4))(obj_bound[0])
    lb = format_obj.get(obj_type, lambda x: round(x, 4))(obj_bound[1])
    deviation_percentage = round(100 * dev / G._ideal_population, 4)
    if ub != lb:
        title = f"{round(dev, 2)}-person deviation ({deviation_percentage}%), obj_bounds [{ub}, {lb}] {obj_type}"
    else:
        title = f"{round(dev, 2)}-person deviation ({deviation_percentage}%), with {ub} {obj_type}"

    draw_plan(filepath, filename2, G, plan, title=title, year=year)
# Out:
# ####################################################################################################
# Pareto maps for state ME, objective average_Polsby_Popper
# ####################################################################################################
