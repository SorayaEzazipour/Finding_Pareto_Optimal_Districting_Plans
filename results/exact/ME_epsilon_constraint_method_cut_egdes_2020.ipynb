# %%
state = 'ME' 
year = 2020

# %%
import sys, os
src_path = os.path.abspath(os.path.join('..', '..', 'src'))
sys.path.append(src_path)

# %%
filepath = '../../dat/' + str(year) + '/'
filename = state + '_county.json'
filename2 = state + '_county.shp'

# %%
from read import read_graph_from_json
from epsilon_constraint import*
import networkx as nx

G = read_graph_from_json(state, filepath + filename, year=year)
print(f"The state of {state} has {G._k} districts.")
G._ideal_population = sum(G.nodes[i]['TOTPOP'] for i in G.nodes) / G._k
# Out:
# The state of ME has 2 districts.

# %%
#import warm starts
sys.path.append(os.path.abspath('../heuristic'))

from ME_plans_2020 import plans
print(f"Loaded {len(plans)} plans from file.")
warm_starts = plans
# Out:
# Loaded 18 plans from file.

# %%
obj_type = 'cut_edges'
starting_deviation = 0.01 
verbose = True
contiguity = 'lcut'               # {'lcut', 'scf', 'shir'}
warm_start_mode = 'user'          # {'None', 'user', 'refinement'}
warm_starts = warm_starts         # if you have user define warm starts else it is None
time_limit = 7200                 # Time limit in seconds, adjust as needed
multiplier = 0                    # Adjust multiplier as needed
max_B = True                      # If symmetry_breaking is 'orbitope' or you have warm_start, max_B should be True
symmetry_breaking = 'orbitope'    # {None, 'orbitope', 'rsum'}              
sizes = None

# %%
print(f"Running epsilon constraint method for state {state}, objective {obj_type}")
print(f"{'#' * 100}\n")
(plans, obj_bounds, deviations) = epsilon_constraint_method(
            G,                 
            obj_type,          
            contiguity,        
            cutoff=None,       
            verbose=verbose,
            warm_start_mode = warm_start_mode,
            warm_starts=warm_starts,  
            starting_deviation=starting_deviation, 
            time_limit=time_limit, 
            sizes=sizes,      
            max_B=max_B,      
            symmetry_breaking=symmetry_breaking, 
            state=state,
            year=year
        )
# Out:
# Running epsilon constraint method for state ME, objective cut_edges
# ####################################################################################################
#
# L = 674368 and U = 687991
#
# ****************************************
# Trying deviation = 6811.795
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[0, 3, 6, 12], [1, 2, 4, 5, 7, 8, 9, 10, 11, 13, 14, 15]]
# Objective value: 5
# Deviation: 2777.5
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 674368 and U = 687991
# Set parameter Username
# Set parameter LicenseID to value 2608266
# Academic license - for non-commercial use only - expires 2026-01-09
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 452 rows, 364 columns and 1323 nonzeros
# Model fingerprint: 0x81ff9b78
# Variable types: 96 continuous, 268 integer (268 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 5 (0.02s)
# Loaded user MIP start with objective 5
#
# Presolve removed 266 rows and 192 columns
# Presolve time: 0.00s
# Presolved: 186 rows, 172 columns, 577 nonzeros
# Variable types: 0 continuous, 172 integer (172 binary)
#
# Root relaxation: objective 2.694842e+00, 88 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.69484    0   22    5.00000    2.69484  46.1%     -    0s
#      0     0     cutoff    0         5.00000    5.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#   RLT: 4
#
# Explored 1 nodes (130 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 5
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
#
# User-callback calls 231, time in user-callback 0.03 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[0, 3, 6, 12], [1, 2, 4, 5, 7, 8, 9, 10, 11, 13, 14, 15]]
#
# ****************************************
# Trying deviation = 2777.25
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[0, 5, 6, 7, 8, 13], [1, 2, 3, 4, 9, 10, 11, 12, 14, 15]]
# Objective value: 11
# Deviation: 1882.5
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 678403 and U = 683956
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 452 rows, 364 columns and 1323 nonzeros
# Model fingerprint: 0x27b1f73a
# Variable types: 96 continuous, 268 integer (268 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 11 (0.02s)
# Loaded user MIP start with objective 11
#
# Presolve removed 266 rows and 192 columns
# Presolve time: 0.00s
# Presolved: 186 rows, 172 columns, 577 nonzeros
# Variable types: 0 continuous, 172 integer (172 binary)
#
# Root relaxation: objective 2.710966e+00, 88 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.71097    0   22   11.00000    2.71097  75.4%     -    0s
#      0     0    3.93987    0   32   11.00000    3.93987  64.2%     -    0s
#      0     0    4.24775    0   36   11.00000    4.24775  61.4%     -    0s
#      0     0    4.62768    0   47   11.00000    4.62768  57.9%     -    0s
#      0     0    4.84622    0   43   11.00000    4.84622  55.9%     -    0s
#      0     0    4.84816    0   41   11.00000    4.84816  55.9%     -    0s
#      0     0    5.00000    0   44   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   34   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   45   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   22   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   28   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   32   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   25   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   32   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   45   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   25   11.00000    5.00000  54.5%     -    0s
#      0     0    5.00000    0   25   11.00000    5.00000  54.5%     -    0s
#      0     2    5.02158    0   25   11.00000    5.02158  54.3%     -    0s
#
# Cutting planes:
#   Cover: 3
#   MIR: 5
#   GUB cover: 1
#   Zero half: 8
#   RLT: 11
#   BQP: 1
#   Lazy constraints: 2
#
# Explored 115 nodes (2345 simplex iterations) in 0.25 seconds (0.04 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 11
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
#
# User-callback calls 589, time in user-callback 0.02 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[1, 2, 3, 4, 9, 10, 11, 12, 14, 15], [0, 5, 6, 7, 8, 13]]
#
# ****************************************
# Trying deviation = 1882.25
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[1, 4, 5, 6, 7, 8, 13, 15], [0, 2, 3, 9, 10, 11, 12, 14]]
# Objective value: 14
# Deviation: 1483.5
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 679298 and U = 683061
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 452 rows, 364 columns and 1323 nonzeros
# Model fingerprint: 0x3d401c74
# Variable types: 96 continuous, 268 integer (268 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 14 (0.01s)
# Loaded user MIP start with objective 14
#
# Presolve removed 263 rows and 190 columns
# Presolve time: 0.01s
# Presolved: 189 rows, 174 columns, 588 nonzeros
# Variable types: 0 continuous, 174 integer (174 binary)
#
# Root relaxation: objective 2.565107e+00, 90 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.56511    0   20   14.00000    2.56511  81.7%     -    0s
#      0     0    4.00284    0   36   14.00000    4.00284  71.4%     -    0s
#      0     0    4.33912    0   35   14.00000    4.33912  69.0%     -    0s
#      0     0    4.68566    0   45   14.00000    4.68566  66.5%     -    0s
#      0     0    4.70590    0   42   14.00000    4.70590  66.4%     -    0s
#      0     0    4.78505    0   45   14.00000    4.78505  65.8%     -    0s
#      0     0    4.78711    0   54   14.00000    4.78711  65.8%     -    0s
#      0     0    4.93449    0   53   14.00000    4.93449  64.8%     -    0s
#      0     0    4.93943    0   53   14.00000    4.93943  64.7%     -    0s
#      0     0    5.17054    0   61   14.00000    5.17054  63.1%     -    0s
#      0     0    5.17054    0   62   14.00000    5.17054  63.1%     -    0s
#      0     0    5.18128    0   66   14.00000    5.18128  63.0%     -    0s
#      0     0    5.18721    0   71   14.00000    5.18721  62.9%     -    0s
#      0     0    5.21855    0   73   14.00000    5.21855  62.7%     -    0s
#      0     0    5.26183    0   71   14.00000    5.26183  62.4%     -    0s
#      0     0    5.26599    0   59   14.00000    5.26599  62.4%     -    0s
#      0     0    5.26786    0   62   14.00000    5.26786  62.4%     -    0s
#      0     0    5.26807    0   62   14.00000    5.26807  62.4%     -    0s
#      0     0    5.28992    0   75   14.00000    5.28992  62.2%     -    0s
#      0     0    5.29383    0   75   14.00000    5.29383  62.2%     -    0s
#      0     0    5.29482    0   72   14.00000    5.29482  62.2%     -    0s
#      0     0    5.35490    0   74   14.00000    5.35490  61.8%     -    0s
#      0     0    5.35612    0   73   14.00000    5.35612  61.7%     -    0s
#      0     0    5.35665    0   76   14.00000    5.35665  61.7%     -    0s
#      0     0    5.37524    0   76   14.00000    5.37524  61.6%     -    0s
#      0     0    5.38496    0   77   14.00000    5.38496  61.5%     -    0s
#      0     0    5.38876    0   80   14.00000    5.38876  61.5%     -    0s
#      0     0    5.39361    0   78   14.00000    5.39361  61.5%     -    0s
#      0     0    5.39378    0   80   14.00000    5.39378  61.5%     -    0s
#      0     0    5.39766    0   76   14.00000    5.39766  61.4%     -    0s
#      0     0    5.39886    0   75   14.00000    5.39886  61.4%     -    0s
#      0     0    5.40093    0   79   14.00000    5.40093  61.4%     -    0s
#      0     0    5.40099    0   80   14.00000    5.40099  61.4%     -    0s
#      0     0    5.40518    0   80   14.00000    5.40518  61.4%     -    0s
#      0     0    5.40518    0   79   14.00000    5.40518  61.4%     -    0s
#      0     2    5.40890    0   79   14.00000    5.40890  61.4%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 14
#   MIR: 5
#   StrongCG: 5
#   Zero half: 8
#   RLT: 16
#   Lazy constraints: 9
#
# Explored 163 nodes (2606 simplex iterations) in 0.34 seconds (0.06 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 14
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
#
# User-callback calls 769, time in user-callback 0.02 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[1, 4, 5, 6, 7, 8, 13, 15], [0, 2, 3, 9, 10, 11, 12, 14]]
#
# ****************************************
# Trying deviation = 1483.25
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[5, 6, 7, 8, 10, 12, 13, 14], [0, 1, 2, 3, 4, 9, 11, 15]]
# Objective value: 15
# Deviation: 750.5
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 679697 and U = 682662
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 452 rows, 364 columns and 1323 nonzeros
# Model fingerprint: 0x1662f5cd
# Variable types: 96 continuous, 268 integer (268 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 15 (0.01s)
# Loaded user MIP start with objective 15
#
# Presolve removed 263 rows and 190 columns
# Presolve time: 0.00s
# Presolved: 189 rows, 174 columns, 588 nonzeros
# Variable types: 0 continuous, 174 integer (174 binary)
#
# Root relaxation: objective 2.566613e+00, 91 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.56661    0   20   15.00000    2.56661  82.9%     -    0s
#      0     0    4.33566    0   45   15.00000    4.33566  71.1%     -    0s
#      0     0    5.24687    0   70   15.00000    5.24687  65.0%     -    0s
#      0     0    5.25345    0   71   15.00000    5.25345  65.0%     -    0s
#      0     0    5.44384    0   78   15.00000    5.44384  63.7%     -    0s
#      0     0    5.44638    0   77   15.00000    5.44638  63.7%     -    0s
#      0     0    5.56999    0   66   15.00000    5.56999  62.9%     -    0s
#      0     0    5.59041    0   66   15.00000    5.59041  62.7%     -    0s
#      0     0    5.61488    0   63   15.00000    5.61488  62.6%     -    0s
#      0     0    5.61522    0   63   15.00000    5.61522  62.6%     -    0s
#      0     0    5.61628    0   64   15.00000    5.61628  62.6%     -    0s
#      0     0    5.61764    0   64   15.00000    5.61764  62.5%     -    0s
#      0     0    5.65422    0   79   15.00000    5.65422  62.3%     -    0s
#      0     0    5.65447    0   77   15.00000    5.65447  62.3%     -    0s
#      0     0    5.66663    0   82   15.00000    5.66663  62.2%     -    0s
#      0     0    5.66663    0   83   15.00000    5.66663  62.2%     -    0s
#      0     0    5.66663    0   77   15.00000    5.66663  62.2%     -    0s
#      0     2    5.67773    0   75   15.00000    5.67773  62.1%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 11
#   MIR: 2
#   StrongCG: 1
#   GUB cover: 1
#   Mod-K: 1
#   RLT: 20
#   BQP: 2
#   Lazy constraints: 10
#
# Explored 283 nodes (3328 simplex iterations) in 0.32 seconds (0.06 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 15
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
#
# User-callback calls 925, time in user-callback 0.02 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[5, 6, 7, 8, 10, 12, 13, 14], [0, 1, 2, 3, 4, 9, 11, 15]]
#
# ****************************************
# Trying deviation = 750.25
# ****************************************
# Using user-provided warm starts.
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 680430 and U = 681929
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 452 rows, 364 columns and 1323 nonzeros
# Model fingerprint: 0x4208ccb0
# Variable types: 96 continuous, 268 integer (268 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 266 rows and 192 columns
# Presolve time: 0.01s
# Presolved: 186 rows, 172 columns, 577 nonzeros
# Variable types: 0 continuous, 172 integer (172 binary)
#
# Root relaxation: objective 2.719066e+00, 88 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.71907    0   22          -    2.71907      -     -    0s
#      0     0    4.14111    0   36          -    4.14111      -     -    0s
#      0     0    4.67318    0   46          -    4.67318      -     -    0s
#      0     0    4.68901    0   43          -    4.68901      -     -    0s
#      0     0    4.75189    0   44          -    4.75189      -     -    0s
#      0     0    4.88546    0   43          -    4.88546      -     -    0s
#      0     0    5.01283    0   47          -    5.01283      -     -    0s
#      0     0    5.06642    0   46          -    5.06642      -     -    0s
#      0     0    5.10236    0   49          -    5.10236      -     -    0s
#      0     0    5.10236    0   47          -    5.10236      -     -    0s
#      0     2    5.10842    0   47          -    5.10842      -     -    0s
#
# Cutting planes:
#   Cover: 2
#   MIR: 2
#   StrongCG: 2
#   Zero half: 4
#   RLT: 8
#   Lazy constraints: 29
#
# Explored 483 nodes (4530 simplex iterations) in 0.29 seconds (0.04 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 1281, time in user-callback 0.07 sec
# No feasible solution found.
#
# ****************************************
# No feasible solution found! Gurobi status: 3
# ****************************************

# %%
result = list(zip(plans, obj_bounds , deviations))

# %%
infeasible_region = [0, min(round(r[2],1) for r in result)]
print(f"Infeasible region is: {infeasible_region}")
# Out:
# Infeasible region is: [0, 750.5]

# %%
from metrics import plot_pareto_frontiers

ideal_population= G._ideal_population
plot_pareto_frontiers(
                G,
                method='epsilon_constraint_method',
                plans=None,                                   #if method ='epsilon_constraint_method' is None 
                obj_types=obj_type,                               
                ideal_population=ideal_population,
                state=state,
                filepath=filepath,
                filename2=filename2,
                infeasible_region=infeasible_region,
                year=year,
                result=result                               #if method ='heuristic' is None 
             )
# Out:
# ####################################################################################################
# Pareto Frontier for state ME,  objective cut_edges
# ####################################################################################################
#
# Pareto front plans: [[[5, 6, 7, 8, 10, 12, 13, 14], [0, 1, 2, 3, 4, 9, 11, 15]], [[1, 4, 5, 6, 7, 8, 13, 15], [0, 2, 3, 9, 10, 11, 12, 14]], [[1, 2, 3, 4, 9, 10, 11, 12, 14, 15], [0, 5, 6, 7, 8, 13]], [[0, 3, 6, 12], [1, 2, 4, 5, 7, 8, 9, 10, 11, 13, 14, 15]]]
# Pareto front upper bounds: [[750.5, 15.0], [1483.5, 14.0], [1882.5, 11.0], [2777.5, 5.0]]
# Pareto front lower bounds: [[750.5, 15.0], [1483.5, 14.0], [1882.5, 11.0], [2777.5, 5.0]]

# %%
from draw import *

print(f"\n{'#' * 100}\nPareto maps for state {state}, objective {obj_type}\n{'#' * 100}\n")

format_obj = {
    'bottleneck_Polsby_Popper': lambda x: round(1 /x, 4),
    'cut_edges': lambda x: round(x, 0)}

for plan, obj_bound, dev in result:
    ub = format_obj.get(obj_type, lambda x: round(x, 4))(obj_bound[0])
    lb = format_obj.get(obj_type, lambda x: round(x, 4))(obj_bound[1])
    deviation_percentage = round(100 * dev / G._ideal_population, 4)
    if ub != lb:
        title = f"{round(dev, 2)}-person deviation ({deviation_percentage}%), obj_bounds [{ub}, {lb}] {obj_type}"
    else:
        title = f"{round(dev, 2)}-person deviation ({deviation_percentage}%), with {ub} {obj_type}"

    draw_plan(filepath, filename2, G, plan, title=title, year=year)
# Out:
# ####################################################################################################
# Pareto maps for state ME, objective cut_edges
# ####################################################################################################
