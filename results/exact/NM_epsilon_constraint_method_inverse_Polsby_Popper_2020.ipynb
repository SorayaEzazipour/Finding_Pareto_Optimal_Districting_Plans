# %%
state = 'NM' 
year = 2020

# %%
import sys, os
src_path = os.path.abspath(os.path.join('..', '..', 'src'))
sys.path.append(src_path)

# %%
filepath = '../../dat/' + str(year) + '/'
filename = state + '_county.json'
filename2 = state + '_county.shp'

# %%
from read import read_graph_from_json
from epsilon_constraint import*
import networkx as nx

G = read_graph_from_json(state, filepath + filename, year=year)
print(f"The state of {state} has {G._k} districts.")
G._ideal_population = sum(G.nodes[i]['TOTPOP'] for i in G.nodes) / G._k
# Out:
# The state of NM has 3 districts.

# %%
#import warm starts
sys.path.append(os.path.abspath('../heuristic'))

from NM_plans import plans
print(f"Loaded {len(plans)} plans from file.")
warm_starts = plans
# Out:
# Loaded 88 plans from file.

# %%
obj_type = 'inverse_Polsby_Popper'
starting_deviation = 0.01 
verbose = True
contiguity = 'lcut'               # {'lcut', 'scf', 'shir'}
warm_start_mode = 'user'          # {'None', 'user', 'refinement'}
warm_starts = None                # if you have user define warm strats else it is None
time_limit = 7200                 # Time limit in seconds, adjust as needed
multiplier = 0                    # Adjust multiplier as needed
max_B = True                      # If symmetry_breaking is 'orbitope' or you have warm_start, max_B should be True
symmetry_breaking = 'orbitope'    # {None, 'orbitope', 'rsum'}              
sizes = None

# %%
print(f"Running epsilon constraint method for state {state}, objective {obj_type}")
print(f"{'#' * 100}\n")
(plans, obj_bounds, deviations) = epsilon_constraint_method(
            G,                 
            obj_type,          
            contiguity,        
            cutoff=None,       
            verbose=verbose,
            warm_start_mode = warm_start_mode,
            warm_starts=warm_starts,  
            starting_deviation=starting_deviation, 
            time_limit=time_limit, 
            sizes=sizes,      
            max_B=max_B,      
            symmetry_breaking=symmetry_breaking, 
        )
# Out:
# Running epsilon constraint method for state NM, objective inverse_Polsby_Popper
# ####################################################################################################
#
# L = 698783 and U = 712899
#
# ****************************************
# Trying deviation = 7058.406666666667
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 698783 and U = 712899
# Set parameter Username
# Set parameter LicenseID to value 2608266
# Academic license - for non-commercial use only - expires 2026-01-09
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1320 rows, 1128 columns and 4888 nonzeros
# Model fingerprint: 0x093c61ca
# Model has 3 quadratic constraints
# Variable types: 306 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 7e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 800 rows and 554 columns
# Presolve time: 0.01s
# Presolved: 520 rows, 574 columns, 2352 nonzeros
# Presolved model has 3 quadratic constraint(s)
# Variable types: 9 continuous, 565 integer (565 binary)
#
# Root relaxation: objective 2.149751e-02, 179 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02150    0    -          -    0.02150      -     -    0s
#      0     0    0.18997    0  121          -    0.18997      -     -    0s
#      0     0    1.28275    0  128          -    1.28275      -     -    0s
#      0     0    1.28442    0  171          -    1.28442      -     -    0s
#      0     0    1.82487    0  168          -    1.82487      -     -    0s
#      0     0    1.84830    0  185          -    1.84830      -     -    0s
#      0     0    1.95347    0  213          -    1.95347      -     -    0s
#      0     0    1.95869    0  145          -    1.95869      -     -    0s
#      0     0    2.01656    0  248          -    2.01656      -     -    0s
#      0     0    2.01693    0  228          -    2.01693      -     -    0s
#      0     0    2.02171    0  231          -    2.02171      -     -    0s
#      0     0    2.02208    0  232          -    2.02208      -     -    0s
#      0     0    2.02689    0  244          -    2.02689      -     -    0s
#      0     0    2.02703    0  244          -    2.02703      -     -    0s
#      0     2    2.02774    0  244          -    2.02774      -     -    0s
# H  741   588                       3.9484329    2.28047  42.2%  36.4    3s
# H  761   559                       3.1881598    2.28047  28.5%  36.9    3s
# H  813   466                       3.1383474    2.28047  27.3%  37.8    3s
# * 1193   341              26       3.1169877    2.35129  24.6%  33.6    4s
# H 1232   306                       2.8598692    2.35129  17.8%  33.6    4s
# * 1461   106              24       2.7940091    2.35129  15.8%  31.3    4s
# H 1476    32                       2.6620497    2.35129  11.7%  31.1    4s
# H 1534     4                       2.3592836    2.35129  0.34%  30.1    4s
# H 1539     2                       2.3512952    2.35130  0.00%  30.0    4s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 7
#   Implied bound: 1
#   MIR: 2
#   StrongCG: 1
#   Flow cover: 5
#   GUB cover: 1
#   Zero half: 17
#   RLT: 12
#   BQP: 2
#   Lazy constraints: 26
#
# Explored 1540 nodes (48231 simplex iterations) in 4.54 seconds (2.15 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 9: 2.3513 2.35928 2.66205 ... 3.94843
#
# Optimal solution found (tolerance 0.00e+00)
# Warning: max constraint violation (1.0810e-07) exceeds tolerance
# Best objective 2.351295229181e+00, best bound 2.351295229181e+00, gap 0.0000%
#
# User-callback calls 4389, time in user-callback 0.22 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[13, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 18, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]]
#
# ****************************************
# Trying deviation = 5433.166666666705
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 700408 and U = 711273
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1320 rows, 1128 columns and 4888 nonzeros
# Model fingerprint: 0x500c84d6
# Model has 3 quadratic constraints
# Variable types: 306 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 7e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 808 rows and 556 columns
# Presolve time: 0.01s
# Presolved: 512 rows, 572 columns, 2324 nonzeros
# Presolved model has 3 quadratic constraint(s)
# Variable types: 9 continuous, 563 integer (563 binary)
#
# Root relaxation: objective 2.196513e-02, 198 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02197    0    -          -    0.02197      -     -    0s
#      0     0    0.25463    0   99          -    0.25463      -     -    0s
#      0     0    1.09561    0  128          -    1.09561      -     -    0s
#      0     0    1.11079    0  144          -    1.11079      -     -    0s
#      0     0    1.80596    0  168          -    1.80596      -     -    0s
#      0     0    1.96801    0  134          -    1.96801      -     -    0s
#      0     0    1.97063    0  131          -    1.97063      -     -    0s
#      0     0    2.01624    0  152          -    2.01624      -     -    0s
#      0     0    2.01905    0  152          -    2.01905      -     -    0s
#      0     0    2.02842    0  154          -    2.02842      -     -    0s
#      0     0    2.03155    0  156          -    2.03155      -     -    0s
#      0     0    2.03157    0  161          -    2.03157      -     -    0s
#      0     0    2.03300    0  152          -    2.03300      -     -    0s
#      0     0    2.03303    0  153          -    2.03303      -     -    0s
#      0     0    2.03801    0  152          -    2.03801      -     -    0s
#      0     2    2.04132    0  152          -    2.04132      -     -    0s
# H  604   439                       3.4331096    2.25749  34.2%  23.7    1s
# H  610   421                       3.4331096    2.25749  34.2%  23.4    3s
# H  612   400                       3.2645199    2.25749  30.8%  23.3    4s
# H  671   438                       2.9445169    2.26827  23.0%  30.7    4s
# H  705   408                       2.6332943    2.26827  13.9%  31.1    4s
# H  720   329                       2.3592829    2.30978  2.10%  31.1    4s
# Cutting planes:
#   Gomory: 13
#   Cover: 6
#   Implied bound: 3
#   Clique: 4
#   MIR: 1
#   StrongCG: 1
#   Flow cover: 5
#   Zero half: 2
#   RLT: 16
#   BQP: 6
#   Lazy constraints: 11
#
# Explored 803 nodes (24753 simplex iterations) in 4.93 seconds (2.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 5: 2.35928 2.63329 2.94452 ... 3.43311
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.359282893226e+00, best bound 2.359282893226e+00, gap 0.0000%
#
# User-callback calls 2857, time in user-callback 0.13 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]]
#
# ****************************************
# Trying deviation = 3208.4999999999613
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 702633 and U = 709049
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1320 rows, 1128 columns and 4888 nonzeros
# Model fingerprint: 0xb1bcefeb
# Model has 3 quadratic constraints
# Variable types: 306 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 7e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 815 rows and 558 columns
# Presolve time: 0.01s
# Presolved: 505 rows, 570 columns, 2304 nonzeros
# Presolved model has 3 quadratic constraint(s)
# Variable types: 9 continuous, 561 integer (561 binary)
#
# Root relaxation: objective 2.287178e-02, 211 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.02287    0    -          -    0.02287      -     -    0s
#      0     0    0.21714    0  104          -    0.21714      -     -    0s
#      0     0    1.43578    0  124          -    1.43578      -     -    0s
#      0     0    1.91417    0  122          -    1.91417      -     -    0s
#      0     0    1.95782    0  159          -    1.95782      -     -    0s
#      0     0    2.01802    0  145          -    2.01802      -     -    0s
#      0     0    2.02702    0  149          -    2.02702      -     -    0s
#      0     0    2.04261    0  160          -    2.04261      -     -    0s
#      0     0    2.04564    0  159          -    2.04564      -     -    0s
#      0     0    2.05693    0  161          -    2.05693      -     -    0s
#      0     0    2.05701    0  161          -    2.05701      -     -    0s
#      0     0    2.05759    0  158          -    2.05759      -     -    0s
#      0     0    2.06011    0  158          -    2.06011      -     -    0s
#      0     0    2.06163    0  158          -    2.06163      -     -    0s
#      0     2    2.06578    0  158          -    2.06578      -     -    0s
# H  825   575                       2.7544938    2.32126  15.7%  31.9    3s
# H  834   494                       2.4165486    2.32126  3.94%  32.1    3s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 6
#   Implied bound: 2
#   MIR: 3
#   Flow cover: 3
#   GUB cover: 1
#   Zero half: 5
#   RLT: 15
#   BQP: 3
#   Lazy constraints: 45
#
# Explored 957 nodes (29898 simplex iterations) in 3.37 seconds (1.63 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 2.41655 2.75449
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.416548591376e+00, best bound 2.416548591376e+00, gap 0.0000%
#
# User-callback calls 2646, time in user-callback 0.17 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 16, 19, 20, 21, 23, 24, 27, 30, 31]]
#
# ****************************************
# Trying deviation = 1510.4999999999611
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 704331 and U = 707351
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1320 rows, 1128 columns and 4888 nonzeros
# Model fingerprint: 0xb65b2838
# Model has 3 quadratic constraints
# Variable types: 306 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 7e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 836 rows and 573 columns
# Presolve time: 0.02s
# Presolved: 484 rows, 555 columns, 2254 nonzeros
# Presolved model has 3 quadratic constraint(s)
# Variable types: 9 continuous, 546 integer (546 binary)
#
# Root relaxation: objective 1.987082e-01, 175 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.19871    0    9          -    0.19871      -     -    0s
#      0     0    0.67519    0  119          -    0.67519      -     -    0s
#      0     0    0.69705    0  119          -    0.69705      -     -    0s
#      0     0    1.53849    0   64          -    1.53849      -     -    0s
#      0     0    1.54130    0   64          -    1.54130      -     -    0s
#      0     0    1.98224    0   77          -    1.98224      -     -    0s
#      0     0    1.98759    0   81          -    1.98759      -     -    0s
#      0     0    2.08617    0   82          -    2.08617      -     -    0s
#      0     0    2.08972    0   92          -    2.08972      -     -    0s
#      0     0    2.09458    0   92          -    2.09458      -     -    0s
#      0     0    2.09702    0   93          -    2.09702      -     -    0s
#      0     0    2.10380    0   98          -    2.10380      -     -    0s
#      0     0    2.10498    0   99          -    2.10498      -     -    0s
#      0     0    2.10498    0   99          -    2.10498      -     -    0s
#      0     0    2.10498    0   98          -    2.10498      -     -    0s
#      0     0    2.10498    0   98          -    2.10498      -     -    0s
#      0     2    2.11155    0   98          -    2.11155      -     -    0s
# H   61    76                       3.8461517    2.26586  41.1%  35.2    0s
# H   75   105                       3.3909373    2.26586  33.2%  33.7    0s
# H  108   105                       3.3678705    2.26586  32.7%  27.4    0s
# H  108   105                       3.2741246    2.26586  30.8%  27.4    0s
# *  256   130              11       3.2498223    2.39099  26.4%  30.8    0s
# H  405   113                       2.9259345    2.41208  17.6%  26.6    0s
# H  634    11                       2.8674779    2.86748  0.00%  21.9    0s
# H  634    11                       2.8674776    2.86748  0.00%  21.9    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 7
#   Implied bound: 3
#   Clique: 20
#   MIR: 1
#   Zero half: 9
#   RLT: 7
#   Lazy constraints: 52
#
# Explored 644 nodes (14936 simplex iterations) in 0.63 seconds (0.24 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 7: 2.86748 2.92593 3.24982 ... 3.84615
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.867477623199e+00, best bound 2.867477623199e+00, gap 0.0000%
#
# User-callback calls 2005, time in user-callback 0.07 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[13, 18, 25], [0, 1, 3, 4, 6, 9, 10, 12, 14, 16, 17, 20, 22, 26, 28, 29, 32], [2, 5, 7, 8, 11, 15, 19, 21, 23, 24, 27, 30, 31]]
#
# ****************************************
# Trying deviation = 1354.1666666667054
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 704487 and U = 707194
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1320 rows, 1128 columns and 4888 nonzeros
# Model fingerprint: 0xcd507cb0
# Model has 3 quadratic constraints
# Variable types: 306 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 7e+05]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [3e-01, 3e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 849 rows and 580 columns
# Presolve time: 0.03s
# Presolved: 471 rows, 548 columns, 2218 nonzeros
# Presolved model has 3 quadratic constraint(s)
# Variable types: 9 continuous, 539 integer (539 binary)
#
# Root relaxation: objective 6.459416e-01, 181 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.64594    0    7          -    0.64594      -     -    0s
#      0     0    1.51065    0  103          -    1.51065      -     -    0s
#      0     0    2.28803    0   68          -    2.28803      -     -    0s
#      0     0    2.59211    0   75          -    2.59211      -     -    0s
#      0     0    2.59588    0   75          -    2.59588      -     -    0s
#      0     0    2.63923    0   88          -    2.63923      -     -    0s
#      0     0    2.64066    0   91          -    2.64066      -     -    0s
#      0     0    2.64367    0   87          -    2.64367      -     -    0s
#      0     0    2.64706    0   90          -    2.64706      -     -    0s
#      0     0    2.64706    0   93          -    2.64706      -     -    0s
#      0     0    2.64709    0   93          -    2.64709      -     -    0s
#      0     0    2.68275    0   40          -    2.68275      -     -    0s
#      0     0    2.68275    0   35          -    2.68275      -     -    0s
#      0     0    2.68275    0   60          -    2.68275      -     -    0s
#      0     0    2.68275    0   70          -    2.68275      -     -    0s
#      0     0    2.68275    0   70          -    2.68275      -     -    0s
#      0     0    2.68275    0   80          -    2.68275      -     -    0s
#      0     0    2.68275    0   80          -    2.68275      -     -    0s
#      0     0    2.68275    0   84          -    2.68275      -     -    0s
#      0     0    2.68275    0   81          -    2.68275      -     -    0s
#      0     0    2.68275    0   84          -    2.68275      -     -    0s
#      0     0    2.68275    0   81          -    2.68275      -     -    0s
#      0     0    2.68275    0   81          -    2.68275      -     -    0s
#      0     0    2.68275    0   81          -    2.68275      -     -    0s
#      0     2    2.68275    0   81          -    2.68275      -     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 6
#   Implied bound: 1
#   MIR: 4
#   StrongCG: 3
#   Zero half: 3
#   RLT: 12
#   BQP: 1
#   Lazy constraints: 73
#
# Explored 1293 nodes (25584 simplex iterations) in 0.97 seconds (0.33 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 3422, time in user-callback 0.15 sec
# No feasible solution found.
#
# ****************************************
# No feasible solution found! Gurobi status: 3
# ****************************************

# %%
result = list(zip(plans, obj_bounds , deviations))

# %%
# Determine the senses for the Pareto frontier
# Minimize the first objective ('deviation').
# Maximize the second objective for compactness types, otherwise minimize it.
senses = ['min', 'max' if obj_type in ['average_Polsby_Popper','bottleneck_Polsby_Popper'] else 'min']
obj_names = ['deviation_persons', obj_type]
infeasible_region = [0, min(round(r[2],1) for r in result)]

# %%
from pareto import ParetoFrontier

print(f"\n{'#' * 100}\nPareto Frontier for state {state},  objective {obj_type}\n{'#' * 100}\n")
pareto = ParetoFrontier(senses, obj_names, state=state, level='county')

if not  plans:
    print("No plan found!")
else:
    for plan, obj_bound, dev in result:
        upper_bound = [dev,  1/obj_bound[0] if  obj_type == 'bottleneck_Polsby_Popper' else obj_bound[0]]
        lower_bound = [dev,  1/obj_bound[1] if  obj_type == 'bottleneck_Polsby_Popper' else obj_bound[1]]
        
        pareto.add_plan(plan, upper_bound, lower_bound)
            
print("Pareto front plans:", pareto.plans)
print("Pareto front upper bounds:", pareto.upper_bounds)
print("Pareto front lower bounds:", pareto.lower_bounds) 

extra_points = None
extra_colors = None
        
pareto.tighten_lower_bounds()

if infeasible_region[1] > 0.5:
    max_dev = max(upper_bound[0] for upper_bound in pareto.upper_bounds)
    max_obj = max(upper_bound[1] for upper_bound in pareto.upper_bounds)
    min_obj = min(upper_bound[1] for upper_bound in pareto.upper_bounds)
    o1lim=[-1, max_dev+100]
    o2lim=[min_obj*0.9, max_obj*(1.1)]
else:
    o1lim = None
    o2lim = None

pareto.plot_with_custom_x_ranges(method = 'epsilon_constraint_method', 
                                 o1lim=o1lim, o2lim=o2lim, infeasible_region = infeasible_region,
                                 extra_points=extra_points, extra_colors=extra_colors)
# Out:
# ####################################################################################################
# Pareto Frontier for state NM,  objective inverse_Polsby_Popper
# ####################################################################################################
#
# Pareto front plans: [[[13, 18, 25], [0, 1, 3, 4, 6, 9, 10, 12, 14, 16, 17, 20, 22, 26, 28, 29, 32], [2, 5, 7, 8, 11, 15, 19, 21, 23, 24, 27, 30, 31]], [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 16, 19, 20, 21, 23, 24, 27, 30, 31]], [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]], [[13, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 18, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]]]
# Pareto front upper bounds: [[1354.3333333333721, 2.867477623199032], [1510.6666666666279, 2.4165485913760945], [3208.666666666628, 2.3592828932262644], [5433.333333333372, 2.351295229180699]]
# Pareto front lower bounds: [[1354.3333333333721, 2.867477623199032], [1510.6666666666279, 2.4165485913760945], [3208.666666666628, 2.3592828932262644], [5433.333333333372, 2.351295229180699]]

# %%
from draw import *

print(f"\n{'#' * 100}\nPareto maps for state {state}, objective {obj_type}\n{'#' * 100}\n")

format_obj = {
    'bottleneck_Polsby_Popper': lambda x: round(1 /x, 4),
    'cut_edges': lambda x: round(x, 0)}

for plan, obj_bound, dev in result:
    ub = format_obj.get(obj_type, lambda x: round(x, 4))(obj_bound[0])
    lb = format_obj.get(obj_type, lambda x: round(x, 4))(obj_bound[1])
    deviation_percentage = round(100 * dev / G._ideal_population, 4)
    if ub != lb:
        title = f"{round(dev, 2)}-person deviation ({deviation_percentage}%), obj_bounds [{ub}, {lb}] {obj_type}"
    else:
        title = f"{round(dev, 2)}-person deviation ({deviation_percentage}%), with {ub} {obj_type}"

    draw_plan(filepath, filename2, G, plan, title=title, year=year)
# Out:
# ####################################################################################################
# Pareto maps for state NM, objective inverse_Polsby_Popper
# ####################################################################################################
