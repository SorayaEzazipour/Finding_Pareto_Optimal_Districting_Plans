# %%
state = 'NM' 
year = 2020
obj_type = 'perimeter'
starting_deviation = 0.01

# %%
import sys, os
src_path = os.path.abspath(os.path.join('..', '..', 'src'))
sys.path.append(src_path)

# %%
filepath = '../../dat/' + str(year) + '/'
filename = state + '_county.json'
filename2 = state + '_county.shp'

# %%
from read import read_graph_from_json

G = read_graph_from_json(state, filepath + filename, year=year)
print(f"The state of {state} has {G._k} districts.")
G._ideal_population = sum(G.nodes[i]['TOTPOP'] for i in G.nodes) / G._k
# Out:
# The state of NM has 3 districts.

# %%
#import warm starts
sys.path.append(os.path.abspath('../heuristic'))

from NM_plans_2020 import plans
print(f"Loaded {len(plans)} plans from file.")
warm_starts = plans
# Out:
# Loaded 149 plans from file.

# %%
from epsilon_constraint import epsilon_constraint_method

(plans, obj_bounds, deviations) = epsilon_constraint_method(
            G,                 
            obj_type,          
            contiguity = 'lcut',                                             # {'lcut', 'scf', 'shir'} 
            cutoff=None,       
            verbose= True,
            warm_start_mode = 'user',                                        # {'None', 'user', 'refinement'}
            warm_starts=warm_starts,                                         # if you have user define warm starts else it is None
            starting_deviation=starting_deviation, 
            time_limit=7200, 
            sizes=None,      
            max_B=True,                                                      # If symmetry_breaking is 'orbitope' or you have warm_start, max_B should be True   
            symmetry_breaking='orbitope',                                    # {None, 'orbitope', 'rsum'} 
            state=state,
            year=year
        )
# Out:
# Initially, L = 698783 and U = 712899 and k = 3.
#
# ****************************************
# Trying deviation = 7058.406666666667
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[13, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 18, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]]
# Objective value: 47.033937593126964
# Deviation: 5433.333333333372
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 698783 and U = 712899
# Set parameter Username
# Set parameter LicenseID to value 2608266
# Academic license - for non-commercial use only - expires 2026-01-09
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1314 rows, 1119 columns and 4261 nonzeros
# Model fingerprint: 0x1c2d98cd
# Variable types: 297 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+05]
#   Objective range  [4e-02, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 47.0339 (0.02s)
# Loaded user MIP start with objective 47.0339
#
# Presolve removed 800 rows and 554 columns
# Presolve time: 0.02s
# Presolved: 514 rows, 565 columns, 1777 nonzeros
# Variable types: 0 continuous, 565 integer (565 binary)
#
# Root relaxation: objective 3.905656e+01, 357 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   39.05656    0  111   47.03394   39.05656  17.0%     -    0s
#      0     0   41.83791    0  164   47.03394   41.83791  11.0%     -    0s
#      0     0   42.82112    0  176   47.03394   42.82112  8.96%     -    0s
#      0     0   42.83999    0  177   47.03394   42.83999  8.92%     -    0s
#      0     0   42.84056    0  180   47.03394   42.84056  8.92%     -    0s
#      0     0   42.99682    0  198   47.03394   42.99682  8.58%     -    0s
#      0     0   43.00231    0  194   47.03394   43.00231  8.57%     -    0s
#      0     0   43.01537    0  200   47.03394   43.01537  8.54%     -    0s
#      0     0   43.02177    0  192   47.03394   43.02177  8.53%     -    0s
#      0     0   43.68188    0  222   47.03394   43.68188  7.13%     -    0s
#      0     0   43.68188    0  223   47.03394   43.68188  7.13%     -    0s
#      0     0   43.71852    0  224   47.03394   43.71852  7.05%     -    0s
#      0     0   43.71999    0  225   47.03394   43.71999  7.05%     -    0s
#      0     0   43.74887    0  199   47.03394   43.74887  6.98%     -    0s
#      0     0   43.74895    0  199   47.03394   43.74895  6.98%     -    0s
#      0     0   43.76832    0  220   47.03394   43.76832  6.94%     -    0s
#      0     0   43.77354    0  234   47.03394   43.77354  6.93%     -    0s
#      0     0   43.78321    0  233   47.03394   43.78321  6.91%     -    0s
#      0     2   43.85535    0  233   47.03394   43.85535  6.76%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 5
#   Implied bound: 2
#   Clique: 2
#   MIR: 1
#   Zero half: 10
#   RLT: 21
#   BQP: 3
#
# Explored 23 nodes (1557 simplex iterations) in 0.58 seconds (0.19 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 47.0339
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.703393759313e+01, best bound 4.703393759313e+01, gap 0.0000%
#
# User-callback calls 523, time in user-callback 0.01 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# plan = [[13, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 18, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]]
#
# ****************************************
# Trying deviation = 5433.166666666705
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[13, 25], [1, 3, 5, 6, 9, 10, 14, 15, 17, 18, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 16, 19, 20, 21, 23, 24, 27, 30, 31]]
# Objective value: 47.839336969480144
# Deviation: 3735.333333333372
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 700408 and U = 711273
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1314 rows, 1119 columns and 4261 nonzeros
# Model fingerprint: 0xa3b52701
# Variable types: 297 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+05]
#   Objective range  [4e-02, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 47.8393 (0.02s)
# Loaded user MIP start with objective 47.8393
#
# Presolve removed 808 rows and 556 columns
# Presolve time: 0.02s
# Presolved: 506 rows, 563 columns, 1750 nonzeros
# Variable types: 0 continuous, 563 integer (563 binary)
#
# Root relaxation: objective 4.029433e+01, 314 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   40
work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 50.1837
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.018372373557e+01, best bound 5.018372373557e+01, gap 0.0000%
#
# User-callback calls 690, time in user-callback 0.00 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# plan = [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]]
#
# ****************************************
# Trying deviation = 3208.4999999999613
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 16, 19, 20, 21, 23, 24, 27, 30, 31]]
# Objective value: 50.98912311192004
# Deviation: 1510.6666666666279
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 702633 and U = 709049
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1314 rows, 1119 columns and 4261 nonzeros
# Model fingerprint: 0xce8b02e1
# Variable types: 297 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+05]
#   Objective range  [4e-02, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 50.9891 (0.01s)
# Loaded user MIP start with objective 50.9891
#
# Presolve removed 815 rows and 558 columns
# Presolve time: 0.01s
# Presolved: 499 rows, 561 columns, 1731 nonzeros
# Variable types: 0 continuous, 561 integer (561 binary)
#
# Root relaxation: objective 4.075186e+01, 302 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   40.75186    0  102   50.98912   40.75186  20.1%     -    0s
#      0     0   42.63238    0  122   50.98912   42.63238  16.4%     -    0s
#      0     0   42.67377    0  128   50.98912   42.67377  16.3%     -    0s
#      0     0   42.93412    0  164   50.98912   42.93412  15.8%     -    0s
#      0     0   42.95959    0   68   50.98912   42.95959  15.7%     -    0s
#      0     0   43.55386    0  155   50.98912   43.55386  14.6%     -    0s
#      0     0   43.61058    0  168   50.98912   43.61058  14.5%     -    0s
#      0     0   43.61246    0  168   50.98912   43.61246  14.5%     -    0s
#      0     0   43.89018    0  124   50.98912   43.89018  13.9%     -    0s
#      0     0   43.95770    0   85   50.98912   43.95770  13.8%     -    0s
#      0     0   43.95770    0   85   50.98912   43.95770  13.8%     -    0s
#      0     0   44.05554    0   87   50.98912   44.05554  13.6%     -    0s
#      0     0   44.05897    0   84   50.98912   44.05897  13.6%     -    0s
#      0     0   44.07326    0   88   50.98912   44.07326  13.6%     -    0s
#      0     0   44.11903    0  101   50.98912   44.11903  13.5%     -    0s
#      0     0   44.13588    0   98   50.98912   44.13588  13.4%     -    0s
#      0     0   44.21007    0   96   50.98912   44.21007  13.3%     -    0s
#      0     0   44.23468    0  168   50.98912   44.23468  13.2%     -    0s
#      0     0   44.25014    0  176   50.98912   44.25014  13.2%     -    0s
#      0     0   44.25085    0  183   50.98912   44.25085  13.2%     -    0s
#      0     0   44.27456    0  183   50.98912   44.27456  13.2%     -    0s
#      0     0   44.35542    0  179   50.98912   44.35542  13.0%     -    0s
#      0     0   44.35636    0  177   50.98912   44.35636  13.0%     -    0s
#      0     0   44.37809    0  176   50.98912   44.37809  13.0%     -    0s
#      0     2   44.46589    0  176   50.98912   44.46589  12.8%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 6
#   Implied bound: 2
#   Clique: 1
#   StrongCG: 2
#   Zero half: 12
#   RLT: 8
#   BQP: 1
#   Lazy constraints: 3
#
# Explored 182 nodes (5427 simplex iterations) in 0.68 seconds (0.20 work units)
# Thread count was 20 (of 20 available processors)
# Solution count 1: 50.9891
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.098912311192e+01, best bound 5.098912311192e+01, gap 0.0000%
#
# User-callback calls 890, time in user-callback 0.03 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# plan = [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 16, 19, 20, 21, 23, 24, 27, 30, 31]]
#
# ****************************************
# Trying deviation = 1510.4999999999611
# ****************************************
# Using user-provided warm starts.
# Selected warm_start = [[13, 18, 25], [2, 5, 7, 8, 11, 15, 19, 21, 23, 24, 27, 30, 31], [0, 1, 3, 4, 6, 9, 10, 12, 14, 16, 17, 20, 22, 26, 28, 29, 32]]
# Objective value: 55.50700622138527
# Deviation: 1354.3333333333721
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 704331 and U = 707351
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Applying warm start!
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1314 rows, 1119 columns and 4261 nonzeros
# Model fingerprint: 0x49532b23
# Variable types: 297 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+05]
#   Objective range  [4e-02, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
#
# User MIP start produced solution with objective 55.507 (0.02s)
# Loaded user MIP start with objective 55.507
#
# Presolve removed 836 rows and 573 columns
# Presolve time: 0.02s
# Presolved: 478 rows, 546 columns, 1669 nonzeros
# Variable types: 0 continuous, 546 integer (546 binary)
#
# Root relaxation: objective 4.277339e+01, 272 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   42.77339    0   73   55.50701   42.77339  22.9%     -    0s
#      0     0   44.32129    0  108   55.50701   44.32129  20.2%     -    0s
#      0     0   44.49072    0  120   55.50701   44.49072  19.8%     -    0s
#      0     0   45.91593    0  138   55.50701   45.91593  17.3%     -    0s
#      0     0   45.97007    0  142   55.50701   45.97007  17.2%     -    0s
#      0     0   45.97449    0  142   55.50701   45.97449  17.2%     -    0s
#      0     0   45.97722    0  142   55.50701   45.97722  17.2%     -    0s
#      0     0   46.26749    0  134   55.50701   46.26749  16.6%     -    0s
#      0     0   46.32603    0  135   55.50701   46.32603  16.5%     -    0s
#      0     0   46.32603    0  135   55.50701   46.32603  16.5%     -    0s
#      0     0   46.73347    0  152   55.50701   46.73347  15.8%     -    0s
#      0     0   46.75221    0  181   55.50701   46.75221  15.8%     -    0s
#      0     0   46.82755    0  178   55.50701   46.82755  15.6%     -    0s
#      0     0   46.83656    0  181   55.50701   46.83656  15.6%     -    0s
#      0     0   46.84722    0  181   55.50701   46.84722  15.6%     -    0s
#      0     0   46.84747    0  181   55.50701   46.84747  15.6%     -    0s
#      0     0   46.84766    0  181   55.50701   46.84766  15.6%     -    0s
#      0     0   46.85665    0  180   55.50701   46.85665  15.6%     -    0s
#      0     2   46.95205    0  180   55.50701   46.95205  15.4%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 8
#   Implied bound: 2
#   Clique: 1
#   Zero half: 12
#   RLT: 18
#   Relax-and-lift: 1
#   BQP: 3
#   Lazy constraints: 2
#
# Explored 330 nodes (7728 simplex iterations) in 0.53 seconds (0.17 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 55.507
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.550700622139e+01, best bound 5.550700622139e+01, gap 0.0000%
#
# User-callback calls 1212, time in user-callback 0.02 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# plan = [[13, 18, 25], [0, 1, 3, 4, 6, 9, 10, 12, 14, 16, 17, 20, 22, 26, 28, 29, 32], [2, 5, 7, 8, 11, 15, 19, 21, 23, 24, 27, 30, 31]]
#
# ****************************************
# Trying deviation = 1354.1666666667054
# ****************************************
# Using user-provided warm starts.
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 704487 and U = 707194
# sizes =  [1, 1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1314 rows, 1119 columns and 4261 nonzeros
# Model fingerprint: 0x8f557de7
# Variable types: 297 continuous, 822 integer (822 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+05]
#   Objective range  [4e-02, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 849 rows and 580 columns
# Presolve time: 0.02s
# Presolved: 465 rows, 539 columns, 1628 nonzeros
# Variable types: 0 continuous, 539 integer (539 binary)
#
# Root relaxation: objective 4.571177e+01, 271 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.71177    0  102          -   45.71177      -     -    0s
#      0     0   50.48321    0   44          -   50.48321      -     -    0s
#      0     0   50.66787    0   95          -   50.66787      -     -    0s
#      0     0   50.66795    0   95          -   50.66795      -     -    0s
#      0     0   50.83202    0  111          -   50.83202      -     -    0s
#      0     0   50.85988    0   96          -   50.85988      -     -    0s
#      0     0   50.86615    0  114          -   50.86615      -     -    0s
#      0     0   51.03361    0   90          -   51.03361      -     -    0s
#      0     0   51.04749    0   94          -   51.04749      -     -    0s
#      0     0   51.07096    0   96          -   51.07096      -     -    0s
#      0     0   51.08526    0   95          -   51.08526      -     -    0s
#      0     0   51.35843    0   30          -   51.35843      -     -    0s
#      0     0   51.35843    0   57          -   51.35843      -     -    0s
#      0     0   51.35843    0   43          -   51.35843      -     -    0s
#      0     0   51.35843    0   84          -   51.35843      -     -    0s
#      0     0   51.35843    0   91          -   51.35843      -     -    0s
#      0     0   51.44260    0   79          -   51.44260      -     -    0s
#      0     0   51.59305    0   75          -   51.59305      -     -    0s
#      0     0   51.59444    0   88          -   51.59444      -     -    0s
#      0     0   51.60559    0   91          -   51.60559      -     -    0s
#      0     0   51.61776    0   91          -   51.61776      -     -    0s
#      0     2   51.84916    0   91          -   51.84916      -     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 3
#   MIR: 1
#   RLT: 17
#   BQP: 3
#   Lazy constraints: 74
#
# Explored 691 nodes (11484 simplex iterations) in 0.85 seconds (0.16 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 2033, time in user-callback 0.27 sec
# No feasible solution found.
#
# ****************************************
# No feasible solution found! Gurobi status: 3
# ****************************************
# Total time for filtering dominated plans = 0.01

# %%
result = list(zip(plans, obj_bounds , deviations))

# %%
no_solution_region = [0, min(round(r[2],1) for r in result)]
print(f"No feasible solution was found within the region: {no_solution_region}")
# Out:
# No feasible solution was found within the region: [0, 1354.3]

# %%
from pareto import plot_pareto_frontiers

plot_pareto_frontiers(
                G,
                method='epsilon_constraint_method',
                plans=None,                                   #if method ='epsilon_constraint_method' is None 
                obj_types=obj_type,                               
                ideal_population=G._ideal_population,
                state=state,
                filepath=filepath,
                filename2=filename2,
                no_solution_region=no_solution_region,
                year=year,
                result=result                               #if method ='heuristic' is None 
             )
# Out:
# ####################################################################################################
# Pareto Frontier for state NM,  objective perimeter
# ####################################################################################################
#
# Pareto front plans: [[[13, 18, 25], [0, 1, 3, 4, 6, 9, 10, 12, 14, 16, 17, 20, 22, 26, 28, 29, 32], [2, 5, 7, 8, 11, 15, 19, 21, 23, 24, 27, 30, 31]], [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 16, 19, 20, 21, 23, 24, 27, 30, 31]], [[13, 18, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]], [[13, 25], [1, 3, 5, 6, 9, 10, 14, 15, 17, 18, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 16, 19, 20, 21, 23, 24, 27, 30, 31]], [[13, 25], [1, 3, 5, 6, 9, 10, 14, 15, 16, 17, 18, 22, 26, 28, 29, 32], [0, 2, 4, 7, 8, 11, 12, 19, 20, 21, 23, 24, 27, 30, 31]]]
# Pareto front upper bounds: [[1354.3333333333721, 55.50700622138527], [1510.6666666666279, 50.989123111920044], [3208.666666666628, 50.183723735566865], [3735.333333333372, 47.839336969480144], [5433.333333333372, 47.033937593126964]]
# Pareto front lower bounds: [[1354.3333333333721, 55.50700622138527], [1510.6666666666279, 50.989123111920044], [3208.666666666628, 50.183723735566865], [3735.333333333372, 47.839336969480144], [5433.333333333372, 47.033937593126964]]

# %%
from draw import draw_plan
from metrics import observed_deviation_persons, compute_obj

print(f"\n{'#' * 100}\nPareto maps for state {state}, objective {obj_type}\n{'#' * 100}\n")

format_obj = {
    'bottleneck_Polsby_Popper': lambda x: round(1 /x, 4),
    'cut_edges': lambda x: int(x)}
G._L = 0
G._U = G._k * G._ideal_population

for plan, obj_bound, dev in result:
    obs_dev = observed_deviation_persons(G, plan, G._ideal_population)
    obj = compute_obj(G, plan, obj_type)
    obj_val = format_obj.get(obj_type, lambda x: round(x, 4))(obj)
    deviation_percentage = round(100 * dev / G._ideal_population, 4)
    title = f"{round(obs_dev, 2)}-person deviation ({deviation_percentage}%), with {obj_val} {obj_type}"
    draw_plan(filepath, filename2, G, plan, title=title, year=year)
# Out:
# ####################################################################################################
# Pareto maps for state NM, objective perimeter
# ####################################################################################################
