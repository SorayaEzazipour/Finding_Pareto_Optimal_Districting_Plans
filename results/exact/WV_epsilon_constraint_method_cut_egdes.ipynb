
#
# Cutting planes:
#   Gomory: 2
#   Clique: 3
#   Inf proof: 2
#   Zero half: 3
#   Lazy constraints: 78
#
# Explored 122 nodes (5677 simplex iterations) in 0.46 seconds (0.10 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 12 17 20
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
#
# User-callback calls 679, time in user-callback 0.19 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[0, 4, 8, 13, 17, 18, 19, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 50, 52, 54], [1, 2, 3, 5, 6, 7, 9, 10, 11, 12, 14, 15, 16, 20, 21, 22, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 49, 51, 53]]
#
# ****************************************
# Trying deviation = 7757.75
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 889101 and U = 904615
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1625 rows, 1300 columns and 4787 nonzeros
# Model fingerprint: 0xb783c6c9
# Variable types: 330 continuous, 970 integer (970 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 936 rows and 650 columns
# Presolve time: 0.01s
# Presolved: 689 rows, 650 columns, 2148 nonzeros
# Variable types: 0 continuous, 650 integer (650 binary)
#
# Root relaxation: objective 4.960975e+00, 496 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.96098    0   59          -    4.96098      -     -    0s
#      0     0    5.51219    0   62          -    5.51219      -     -    0s
#      0     0    6.06330    0   65          -    6.06330      -     -    0s
#      0     0    6.09094    0   69          -    6.09094      -     -    0s
#      0     0    6.09094    0   69          -    6.09094      -     -    0s
#      0     2    6.09578    0   69          -    6.09578      -     -    0s
# H   10    16                      17.0000000    8.84473  48.0%  83.5    0s
# H   15    26                      16.0000000    9.07727  43.3%  73.6    0s
# H   67    52                      15.0000000    9.64990  35.7%  63.8    0s
# H  125    77                      14.0000000   10.09387  27.9%  51.3    0s
# H  128    77                      13.0000000   10.09387  22.4%  50.3    0s
# H  161    77                      12.0000000   10.44323  13.0%  48.0    0s
#
# Cutting planes:
#   Gomory: 2
#   Clique: 3
#   Zero half: 3
#   Lazy constraints: 57
#
# Explored 225 nodes (9270 simplex iterations) in 0.43 seconds (0.11 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 6: 12 13 14 ... 17
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
#
# User-callback calls 878, time in user-callback 0.17 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[0, 2, 4, 6, 8, 13, 17, 19, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 50, 52, 54], [1, 3, 5, 7, 9, 10, 11, 12, 14, 15, 16, 18, 20, 21, 22, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 49, 51, 53]]
#
# ****************************************
# Trying deviation = 2375.75
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 894483 and U = 899233
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1625 rows, 1300 columns and 4787 nonzeros
# Model fingerprint: 0xecaed23b
# Variable types: 330 continuous, 970 integer (970 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 936 rows and 650 columns
# Presolve time: 0.01s
# Presolved: 689 rows, 650 columns, 2148 nonzeros
# Variable types: 0 continuous, 650 integer (650 binary)
#
# Root relaxation: objective 4.991005e+00, 391 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.99101    0   59          -    4.99101      -     -    0s
#      0     0    5.54556    0   62          -    5.54556      -     -    0s
#      0     0    5.87739    0   65          -    5.87739      -     -    0s
# H    0     0                      23.0000000    5.87739  74.4%     -    0s
# H    0     0                      18.0000000    5.87739  67.3%     -    0s
#      0     0    5.99389    0   65   18.00000    5.99389  66.7%     -    0s
#      0     0    6.02005    0   68   18.00000    6.02005  66.6%     -    0s
#      0     0    6.06448    0   71   18.00000    6.06448  66.3%     -    0s
#      0     0    6.14473    0   74   18.00000    6.14473  65.9%     -    0s
#      0     0    6.41634    0   81   18.00000    6.41634  64.4%     -    0s
#      0     0    6.41634    0   81   18.00000    6.41634  64.4%     -    0s
#      0     2    6.41656    0   81   18.00000    6.41656  64.4%     -    0s
# H  145   108                      17.0000000    9.78819  42.4%  55.6    0s
# H  177   114                      15.0000000    9.78819  34.7%  51.8    0s
# H  337    77                      13.0000000   11.00414  15.4%  46.3    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Clique: 6
#   Inf proof: 4
#   Zero half: 6
#   RLT: 1
#   Lazy constraints: 45
#
# Explored 472 nodes (18928 simplex iterations) in 0.51 seconds (0.19 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 5: 13 15 17 ... 23
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
#
# User-callback calls 1411, time in user-callback 0.11 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[0, 2, 4, 6, 9, 13, 17, 19, 22, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 49, 50, 51, 52, 54], [1, 3, 5, 7, 8, 10, 11, 12, 14, 15, 16, 18, 20, 21, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 53]]
#
# ****************************************
# Trying deviation = 223.75
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L =

#
# Cutting planes:
#   Gomory: 2
#   Zero half: 3
#   Lazy constraints: 62
#
# Explored 19907 nodes (398364 simplex iterations) in 2.76 seconds (1.17 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 20
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
#
# User-callback calls 40694, time in user-callback 0.36 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[0, 1, 2, 5, 6, 9, 13, 17, 19, 22, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 49, 50, 52, 54], [3, 4, 7, 8, 10, 11, 12, 14, 15, 16, 18, 20, 21, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 51, 53]]
#
# ****************************************
# Trying deviation = 1.75
# ****************************************
# No valid warm start used.
#
# ****************************************
# Running labeling model!
# ****************************************
# L = 896857 and U = 896859
# sizes =  [1, 1]
# Solving the max B problem (as MIP) for use in the vertex ordering...
# Set parameter LogToConsole to value 0
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter TimeLimit to value 7200
# Set parameter IntFeasTol to value 1e-07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  7200
# FeasibilityTol  1e-07
# IntFeasTol  1e-07
# MIPGap  0
# LazyConstraints  1
#
# Optimize a model with 1625 rows, 1300 columns and 4787 nonzeros
# Model fingerprint: 0x3d2602a9
# Variable types: 330 continuous, 970 integer (970 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+05]
# Presolve removed 936 rows and 650 columns
# Presolve time: 0.01s
# Presolved: 689 rows, 650 columns, 2148 nonzeros
# Variable types: 0 continuous, 650 integer (650 binary)
#
# Root relaxation: objective 5.004252e+00, 486 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.00425    0   59          -    5.00425      -     -    0s
#      0     0    5.56028    0   62          -    5.56028      -     -    0s
#      0     0    6.08581    0   65          -    6.08581      -     -    0s
#      0     0    6.08581    0   66          -    6.08581      -     -    0s
#      0     0    6.08672    0   68          -    6.08672      -     -    0s
#      0     0    6.08856    0   69          -    6.08856      -     -    0s
#      0     0    6.08856    0   68          -    6.08856      -     -    0s
#      0     2    6.09061    0   68          -    6.09061      -     -    0s
#  52785 31704 infeasible   53               -   15.59975      -  15.9    5s
#  114642 64283   28.07507   33   55          -   17.18776      -  14.8   10s
#  165225 88084   38.00000   42   13          -   18.17711      -  15.2   15s
# *182727 36229              43      27.0000000   18.50031  31.5%  15.3   16s
#  209823 35700   25.12428   33   35   27.00000   20.00000  25.9%  15.7   20s
# *255813 12076              38      24.0000000   21.50696  10.4%  16.2   24s
# *259511  1162              33      23.0000000   21.76941  5.35%  16.1   24s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 3
#   Lazy constraints: 112
#
# Explored 261631 nodes (4216698 simplex iterations) in 25.06 seconds (10.25 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 23 24 27
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
#
# User-callback calls 529527, time in user-callback 2.10 sec
#
# ****************************************
# Optimal solution found! Gurobi status: 2
# ****************************************
# [[0, 2, 4, 6, 8, 9, 13, 17, 19, 20, 22, 23, 26, 28, 29, 31, 33, 34, 36, 42, 43, 45, 50, 51, 54], [1, 3, 5, 7, 10, 11, 12, 14, 15, 16, 18, 21, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 44, 46, 47, 48, 49, 52, 53]]
# Deviation is too small, stopping early.

# %%
result = list(zip(plans, obj_bounds , deviations))

# %%
if state == "ME":
    infeasible_region = [0, 750]
elif  state == "NM":
    infeasible_region = [0, 1354]
else:
    infeasible_region = None

# %%
# Determine the senses for the Pareto frontier
# Minimize the first objective ('deviation').
# Maximize the second objective for compactness types, otherwise minimize it.
senses = ['min', 'max' if obj_type in ['average_Polsby_Popper','bottleneck_Polsby_Popper'] else 'min']
obj_names = ['deviation_persons', obj_type]

# %%
from pareto import ParetoFrontier

print(f"\n{'#' * 100}\nPareto Frontier for state {state},  objective {obj_type}\n{'#' * 100}\n")
pareto = ParetoFrontier(senses, obj_names, state=state, level='county')

if not  plans:
    print("No plan found!")
else:
    for plan, obj_bound, dev in result:
        upper_bound = [dev,  1/obj_bound[0] if  obj_type == 'bottleneck_Polsby_Popper' else obj_bound[0]]
        lower_bound = [dev,  1/obj_bound[1] if  obj_type == 'bottleneck_Polsby_Popper' else obj_bound[1]]
            
        # Add the plan and its objective values to the Pareto frontier
        pareto.add_plan(plan, upper_bound, lower_bound)
            
# Print the Pareto frontier plans and objective values
print("Pareto front plans:", pareto.plans)
print("Pareto front upper bounds:", pareto.upper_bounds)
print("Pareto front lower bounds:", pareto.lower_bounds)
    
#extra_points: list of tuples, each containing (deviation, objective_value, label)
if state == 'WV':
    
    #2010 enacted map scores
    enacted_map_deviation = 3197.333333333372
    enacted_map_scores = {'inverse_Polsby_Popper': 7.75, 'cut_edges': 68.00, 
                                      'perimeter': 42.12, 'average_Polsby_Popper': 0.14,'bottleneck_Polsby_Popper': 0.10}
    # Cooper plan 1
    Cooper_plan_1_deviation = 323.66666666662786
    Cooper_plan_1_scores = {'inverse_Polsby_Popper': 7.31, 'cut_edges': 68.00, 
                                      'perimeter': 40.53, 'average_Polsby_Popper': 0.17,'bottleneck_Polsby_Popper': 0.10}
    # Cooper plan 2
    Cooper_plan_2_deviation = 232.66666666662786
    Cooper_plan_2_scores = {'inverse_Polsby_Popper': 8.18, 'cut_edges': 72.00, 
                                      'perimeter': 43.36, 'average_Polsby_Popper': 0.16,'bottleneck_Polsby_Popper': 0.09}
    # Cooper plan 3
    Cooper_plan_3_deviation = 115.66666666662786
    Cooper_plan_3_scores = {'inverse_Polsby_Popper': 7.25, 'cut_edges': 70.00, 
                                      'perimeter': 40.65, 'average_Polsby_Popper': 0.16,'bottleneck_Polsby_Popper': 0.09}
    extra_points = [
                (enacted_map_deviation,  enacted_map_scores[obj_type], 'Enacted Map'),
                (Cooper_plan_1_deviation,  Cooper_plan_1_scores[obj_type] , 'Cooper plan 1'),
                (Cooper_plan_2_deviation,  Cooper_plan_2_scores[obj_type], 'Cooper plan 2'),
                (Cooper_plan_3_deviation, Cooper_plan_3_scores[obj_type], 'Cooper plan 3'),
                        ]
    
    #extra_colors: list of colors corresponding to the points in extra_points
    extra_colors = ['r', 'g', 'c', 'y']  # Red, Green, Cyan, Yellow for each of the extra points
    
    for ep in extra_points:
        print(f"The {ep[2]} has an objective value of {ep[1]} and a deviation of {ep[0]}.")
else:
    extra_points = None
    extra_colors = None
        
pareto.tighten_lower_bounds()
    
if infeasible_region != None:
        
    # Get the max values for setting the limits
    max_dev = max(upper_bound[0] for upper_bound in pareto.upper_bounds)
    max_ce = max(upper_bound[1] for upper_bound in pareto.upper_bounds)
    o1lim=[0, max_dev+100]
    o2lim=[0, max_ce*(1.1)]
else:
    o1lim = None
    o2lim = None

pareto.plot_with_custom_x_ranges(splits=None,o1lim=o1lim, o2lim=o2lim, infeasible_region = infeasible_region, extra_points=extra_points, extra_colors=extra_colors)
# Out:
# ####################################################################################################
# Pareto Frontier for state WV,  objective cut_edges
# ####################################################################################################
#
# Pareto front plans: [[[0, 2, 4, 6, 8, 9, 13, 17, 19, 20, 22, 23, 26, 28, 29, 31, 33, 34, 36, 42, 43, 45, 50, 51, 54], [1, 3, 5, 7, 10, 11, 12, 14, 15, 16, 18, 21, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 44, 46, 47, 48, 49, 52, 53]], [[0, 1, 2, 5, 6, 9, 13, 17, 19, 22, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 49, 50, 52, 54], [3, 4, 7, 8, 10, 11, 12, 14, 15, 16, 18, 20, 21, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 51, 53]], [[0, 2, 4, 5, 6, 7, 9, 13, 17, 18, 19, 22, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 49, 50, 51, 54], [1, 3, 8, 10, 11, 12, 14, 15, 16, 20, 21, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 52, 53]], [[0, 2, 4, 6, 7, 9, 13, 17, 19, 22, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 50, 51, 52, 54], [1, 3, 5, 8, 10, 11, 12, 14, 15, 16, 18, 20, 21, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 49, 53]], [[0, 2, 4, 6, 9, 13, 17, 19, 22, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 49, 50, 51, 52, 54], [1, 3, 5, 7, 8, 10, 11, 12, 14, 15, 16, 18, 20, 21, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 53]], [[0, 2, 4, 6, 8, 13, 17, 19, 23, 26, 28, 29, 31, 33, 34, 36, 42, 45, 50, 52, 54], [1, 3, 5, 7, 9, 10, 11, 12, 14, 15, 16, 18, 20, 21, 22, 24, 25, 27, 30, 32, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 48, 49, 51, 53]]]
# Pareto front upper bounds: [[0.0, 23.0], [2.0, 20.0], [13.0, 18.0], [38.0, 13.999999999999998], [224.0, 13.0], [2376.0, 12.0]]
# Pareto front lower bounds: [[0.0, 23.0], [2.0, 20.0], [13.0, 18.0], [38.0, 13.999999999999998], [224.0, 13.0], [2376.0, 12.0]]
# The Enacted Map has an objective value of 68.0 and a deviation of 3197.333333333372.
# The Cooper plan 1 has an objective value of 68.0 and a deviation of 323.66666666662786.
# The Cooper plan 2 has an objective value of 72.0 and a deviation of 232.66666666662786.
# The Cooper plan 3 has an objective value of 70.0 and a deviation of 115.66666666662786.

# %%
from draw import*

print(f"\n{'#' * 100}\nPareto maps for state {state},  objective {obj_type}\n{'#' * 100}\n")   
for plan, obj_bound, dev in result:
    title = f"{round(dev,2)}-person deviation ({round(100*dev/G._ideal_population,4)}%), obj_bounds {(round(obj_bound[0],2),round(obj_bound[1],2))} {obj_type}"
    draw_plan( filepath, filename2, G, plan, title=title, year=year )
# Out:
# ####################################################################################################
# Pareto maps for state WV,  objective cut_edges
# ####################################################################################################
